# %%
from matplotlib import pyplot as plt
import numpy as np

fig,axes = plt.subplots(2,3,tight_layout=True)

y0 = [1,2,-5,2]
axes[0,0].plot(y0)

x1 = np.linspace(0, 10, 100)
y1 = 2 + 2 * np.sin(2 * x1)
# プロット
axes[0,1].plot(x, y)
axes[0,1].set(xlim=(0, 10), xticks=np.arange(0, 10),
              ylim=(-1, 5), yticks=np.arange(-1, 6))

y2 = np.random.normal(15,5,2000)
axes[0,2].hist(y2)
axes[0,2].set(ylim=(0, 600), yticks=np.arange(0, 600, 200))

np.random.seed(3)
x3 = 4 + np.random.normal(0,2,60)
y3 = 4 + np.random.normal(0,2,len(x3))
axes[1,0].scatter(x3,y3)
axes[1,0].set(ylim=(-2.5, 10), yticks=np.arange(0, 10, 2.5))
# Out:
# [(-2.5, 10.0),
#  [<matplotlib.axis.YTick at 0x7fa28d8a0820>,
#   <matplotlib.axis.YTick at 0x7fa28d8a3850>,
#   <matplotlib.axis.YTick at 0x7fa28d8badd0>,
#   <matplotlib.axis.YTick at 0x7fa28d6dca30>]]
